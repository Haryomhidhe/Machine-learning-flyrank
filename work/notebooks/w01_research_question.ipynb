# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Haryomhidhe/Machine-learning-flyrank/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
#
# My lane is Refresh and Opportunity Scoring. I'm choosing this because it directly matches the kind of decision I framed in Section 2 — ranking pages by opportunity so an editor knows which ones to review first. I also already have evidence this works from my own notebooks: a hand-made rule scored 0.240 on precision, but a random forest model scored 0.740, showing there's real signal in this data for this type of ranking problem

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# A content editor is deciding which pages to review first, out of all the pages on the client's site. For each page they open, they decide whether to refresh it, expand it, protect it as-is, or prune it. If the ranking is wrong and a genuinely declining page gets skipped, it keeps losing search visibility and traffic while nobody catches it in time before the damage compounds

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
#
# We picked three numbers: search volume, engagement rate, and scroll rate, compared across two pages. Page zero has a search volume of ten, engagement rate five point eight eight, and scroll rate four point five zero — low traffic, but people who arrive actually engage. Page one has a search volume of ninety, engagement rate zero, and scroll rate ten — high traffic, but people land on it and scroll straight past without engaging. Page one is the bigger opportunity because real traffic is already arriving and being wasted, which is exactly the kind of gap Refresh and Opportunity Scoring is meant to catch

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# **What I can claim (Observed / Directional / Decision-Support):**
#
# * **Observed patterns:** Page one generates high search volume and high scroll rates, but yields near-zero meaningful engagement.
# * **Directional insight:** Traffic is arriving and skimming, but failing to convert into actual readership—signaling a severe retention bottleneck.
# * **Decision-support:** The data identifies page one as an immediate priority for optimization or content restructuring to capture lost traffic value.
#
# **What I cannot claim (Causal Proof / Predictive):**
#
# * **Causal proof:** The metrics cannot diagnose *why* users leave. They do not prove whether the issue is weak content quality, misaligned search intent, framing problems, or superior competitor pages.
# * **Algorithmic certainty:** The data flags user drop-off symptoms, but cannot predict search algorithm behavior or prove how specific changes will guarantee ranking improvements.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [Done] Every section above is filled — markdown thinking AND the code that backs it
# - [Done] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [Done] No client names, URLs, or private queries anywhere
# - [Done] My claims use careful words: observed, measured, directional, decision-support
# - [Done] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
